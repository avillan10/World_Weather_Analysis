# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# # Retrieve Nearest City

# %%
#Create 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 766

# %% [markdown]
# # API Call to OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | tautira
# Processing Record 4 of Set 1 | whitehorse
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | laguna
# Processing Record 7 of Set 1 | port hardy
# Processing Record 8 of Set 1 | ketchikan
# Processing Record 9 of Set 1 | nemuro
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | aktash
# Processing Record 12 of Set 1 | lop buri
# Processing Record 13 of Set 1 | raudeberg
# Processing Record 14 of Set 1 | ussel
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | gizo
# Processing Record 18 of Set 1 | sept-iles
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 1 | nioro
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | ati
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | leek
# Processing Record 29 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | truth or consequences
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | manzhouli
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | plettenberg bay
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | cherskiy
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | bathsheba
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | taoudenni
# Processing Record 4 of Set 2 | algete
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | ulaanbaatar
# Processing Record 7 of Set 2 | agapovka
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | ferkessedougou
# Processing Record 11 of Set 2 | prieska
# Processing Record 12 of Set 2 | tiarei
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | bud
# Processing Record 15 of Set 2 | esperance
# Processing Record 16 of Set 2 | itoman
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 2 | adrar
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | nabire
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | penzance
# Processing Record 25 of Set 2 | sosua
# Processing Record 26 of Set 2 | axim
# Processing Record 27 of Set 2 | yuryevets
# Processing Record 28 of Set 2 | balykshi
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | zhezkazgan
# Processing Record 31 of Set 2 | san antonio
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | wanning
# Processing Record 34 of Set 2 | bac lieu
# Processing Record 35 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | siddharthanagar
# Processing Record 38 of Set 2 | ipameri
# Processing Record 39 of Set 2 | itarema
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | homer
# Processing Record 46 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 47 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | sahbuz
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | husavik
# Processing Record 4 of Set 3 | lusambo
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | yaan
# Processing Record 7 of Set 3 | mezen
# Processing Record 8 of Set 3 | mantua
# Processing Record 9 of Set 3 | lynn haven
# Processing Record 10 of Set 3 | burgersdorp
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | dawlatabad
# Processing Record 13 of Set 3 | zawiercie
# Processing Record 14 of Set 3 | vanimo
# Processing Record 15 of Set 3 | maniitsoq
# Processing Record 16 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | straznice
# Processing Record 19 of Set 3 | pochutla
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | torbay
# Processing Record 23 of Set 3 | kaeo
# Processing Record 24 of Set 3 | kolokani
# Processing Record 25 of Set 3 | carberry
# Processing Record 26 of Set 3 | zhangye
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | saskylakh
# Processing Record 29 of Set 3 | bisira
# Processing Record 30 of Set 3 | lardos
# Processing Record 31 of Set 3 | ailigandi
# Processing Record 32 of Set 3 | asau
# Processing Record 33 of Set 3 | flinders
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | nuuk
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | hobyo
# Processing Record 38 of Set 3 | berezniki
# Processing Record 39 of Set 3 | portland
# Processing Record 40 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 3 | punta arenas
# Processing Record 42 of Set 3 | kharp
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | acarigua
# Processing Record 45 of Set 3 | borzya
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | crateus
# Processing Record 48 of Set 3 | margate
# Processing Record 49 of Set 3 | culiacan
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | shieli
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | pisco
# Processing Record 4 of Set 4 | faya
# Processing Record 5 of Set 4 | labuhan
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | rio gallegos
# Processing Record 8 of Set 4 | lukulu
# Processing Record 9 of Set 4 | ternate
# Processing Record 10 of Set 4 | mana
# Processing Record 11 of Set 4 | marshall
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | ixtapa
# Processing Record 14 of Set 4 | mehamn
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | mizdah
# Processing Record 17 of Set 4 | lavrentiya
# Processing Record 18 of Set 4 | egvekinot
# Processing Record 19 of Set 4 | carmelo
# Processing Record 20 of Set 4 | ostersund
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | minas
# Processing Record 24 of Set 4 | victoria
# Processing Record 25 of Set 4 | chitral
# Processing Record 26 of Set 4 | xuanzhou
# Processing Record 27 of Set 4 | omboue
# Processing Record 28 of Set 4 | tecoanapa
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | meadow lake
# Processing Record 31 of Set 4 | lianyuan
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | hasaki
# Processing Record 34 of Set 4 | juneau
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | monte cristi
# City not found. Skipping...
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | maputo
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | cozumel
# Processing Record 41 of Set 4 | freeport
# Processing Record 42 of Set 4 | ifanadiana
# Processing Record 43 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 4 | xining
# Processing Record 45 of Set 4 | chapais
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | pangkalanbuun
# Processing Record 49 of Set 4 | palmares do sul
# Processing Record 50 of Set 4 | sa kaeo
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | liepaja
# Processing Record 3 of Set 5 | nizhneangarsk
# Processing Record 4 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 5 | grootfontein
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | yellowknife
# Processing Record 9 of Set 5 | plainview
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 5 | foz do iguacu
# Processing Record 14 of Set 5 | tadine
# Processing Record 15 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 5 | ponta do sol
# Processing Record 17 of Set 5 | west plains
# Processing Record 18 of Set 5 | pangnirtung
# Processing Record 19 of Set 5 | acapulco
# Processing Record 20 of Set 5 | idar
# Processing Record 21 of Set 5 | bilibino
# Processing Record 22 of Set 5 | jinka
# Processing Record 23 of Set 5 | aksu
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | fort morgan
# Processing Record 27 of Set 5 | bokoro
# Processing Record 28 of Set 5 | havelock
# Processing Record 29 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | beloha
# Processing Record 31 of Set 5 | sechura
# Processing Record 32 of Set 5 | dharchula
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | valdivia
# Processing Record 35 of Set 5 | chicama
# Processing Record 36 of Set 5 | russell
# Processing Record 37 of Set 5 | baracoa
# Processing Record 38 of Set 5 | songea
# Processing Record 39 of Set 5 | wanaka
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | lerwick
# Processing Record 43 of Set 5 | kalianget
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | avera
# Processing Record 47 of Set 5 | luoyang
# Processing Record 48 of Set 5 | jarinu
# Processing Record 49 of Set 5 | jodhpur
# Processing Record 50 of Set 5 | orotukan
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | qasigiannguit
# Processing Record 3 of Set 6 | tiksi
# Processing Record 4 of Set 6 | kidal
# Processing Record 5 of Set 6 | jesus maria
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | codrington
# Processing Record 8 of Set 6 | acarau
# Processing Record 9 of Set 6 | eenhana
# Processing Record 10 of Set 6 | gazanjyk
# Processing Record 11 of Set 6 | kirakira
# Processing Record 12 of Set 6 | berlevag
# Processing Record 13 of Set 6 | yenagoa
# Processing Record 14 of Set 6 | sol-iletsk
# Processing Record 15 of Set 6 | galesong
# Processing Record 16 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 6 | kwekwe
# Processing Record 18 of Set 6 | baykit
# Processing Record 19 of Set 6 | outjo
# Processing Record 20 of Set 6 | gweta
# Processing Record 21 of Set 6 | muli
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | neveklov
# Processing Record 24 of Set 6 | altay
# Processing Record 25 of Set 6 | leku
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | vyartsilya
# Processing Record 29 of Set 6 | saint-joseph
# Processing Record 30 of Set 6 | kropotkin
# Processing Record 31 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 6 | waynesville
# Processing Record 33 of Set 6 | payo
# Processing Record 34 of Set 6 | san quintin
# Processing Record 35 of Set 6 | lodeynoye pole
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | port moresby
# Processing Record 38 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 39 of Set 6 | santa cruz
# Processing Record 40 of Set 6 | olafsvik
# Processing Record 41 of Set 6 | ust-maya
# Processing Record 42 of Set 6 | samarai
# Processing Record 43 of Set 6 | salinopolis
# Processing Record 44 of Set 6 | carutapera
# Processing Record 45 of Set 6 | los llanos de aridane
# Processing Record 46 of Set 6 | bakchar
# Processing Record 47 of Set 6 | ardakan
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 6 | mumford
# Processing Record 1 of Set 7 | badulla
# Processing Record 2 of Set 7 | hazorasp
# Processing Record 3 of Set 7 | ocean city
# Processing Record 4 of Set 7 | namuac
# Processing Record 5 of Set 7 | beringovskiy
# Processing Record 6 of Set 7 | lovington
# Processing Record 7 of Set 7 | cranbrook
# Processing Record 8 of Set 7 | pangai
# Processing Record 9 of Set 7 | honiara
# Processing Record 10 of Set 7 | harrison
# Processing Record 11 of Set 7 | brae
# Processing Record 12 of Set 7 | ulladulla
# Processing Record 13 of Set 7 | dolores
# Processing Record 14 of Set 7 | inyonga
# Processing Record 15 of Set 7 | silanga
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | vila franca do campo
# Processing Record 18 of Set 7 | kyra
# Processing Record 19 of Set 7 | jiexiu
# Processing Record 20 of Set 7 | storforshei
# Processing Record 21 of Set 7 | dzaoudzi
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | paramonga
# Processing Record 24 of Set 7 | vadso
# Processing Record 25 of Set 7 | loreto
# Processing Record 26 of Set 7 | talnakh
# Processing Record 27 of Set 7 | fjerritslev
# Processing Record 28 of Set 7 | svetlogorsk
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | candido mendes
# Processing Record 31 of Set 7 | haskovo
# Processing Record 32 of Set 7 | lang son
# Processing Record 33 of Set 7 | camflora
# City not found. Skipping...
# Processing Record 34 of Set 7 | rio grande
# Processing Record 35 of Set 7 | krasnoarmeyskoye
# Processing Record 36 of Set 7 | srednekolymsk
# Processing Record 37 of Set 7 | nome
# Processing Record 38 of Set 7 | iqaluit
# Processing Record 39 of Set 7 | floro
# Processing Record 40 of Set 7 | dire dawa
# Processing Record 41 of Set 7 | yulara
# Processing Record 42 of Set 7 | raga
# Processing Record 43 of Set 7 | tahe
# Processing Record 44 of Set 7 | dickinson
# Processing Record 45 of Set 7 | yuxia
# Processing Record 46 of Set 7 | mayo
# Processing Record 47 of Set 7 | hambantota
# Processing Record 48 of Set 7 | ihosy
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | ibimirim
# Processing Record 1 of Set 8 | beibei
# Processing Record 2 of Set 8 | banjar
# Processing Record 3 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 8 | puerto baquerizo moreno
# Processing Record 5 of Set 8 | rafai
# Processing Record 6 of Set 8 | qixingtai
# Processing Record 7 of Set 8 | faanui
# Processing Record 8 of Set 8 | bosaso
# Processing Record 9 of Set 8 | sinnamary
# Processing Record 10 of Set 8 | kupang
# Processing Record 11 of Set 8 | kununurra
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | ruston
# Processing Record 14 of Set 8 | baheri
# Processing Record 15 of Set 8 | ancud
# Processing Record 16 of Set 8 | bambanglipuro
# Processing Record 17 of Set 8 | akyab
# Processing Record 18 of Set 8 | vilyuysk
# Processing Record 19 of Set 8 | taft
# Processing Record 20 of Set 8 | sirawai
# Processing Record 21 of Set 8 | vegreville
# Processing Record 22 of Set 8 | touros
# Processing Record 23 of Set 8 | balabac
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | cidreira
# Processing Record 26 of Set 8 | boende
# Processing Record 27 of Set 8 | winnemucca
# Processing Record 28 of Set 8 | chimbarongo
# Processing Record 29 of Set 8 | honggang
# Processing Record 30 of Set 8 | nynashamn
# Processing Record 31 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 8 | morondava
# Processing Record 33 of Set 8 | lorengau
# Processing Record 34 of Set 8 | vytegra
# Processing Record 35 of Set 8 | atambua
# Processing Record 36 of Set 8 | grand-santi
# Processing Record 37 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 8 | erice
# Processing Record 39 of Set 8 | port hawkesbury
# Processing Record 40 of Set 8 | khani
# Processing Record 41 of Set 8 | vardo
# Processing Record 42 of Set 8 | boralday
# Processing Record 43 of Set 8 | puerto colombia
# Processing Record 44 of Set 8 | apiai
# Processing Record 45 of Set 8 | fuling
# Processing Record 46 of Set 8 | port keats
# Processing Record 47 of Set 8 | prachuap khiri khan
# Processing Record 48 of Set 8 | gambela
# Processing Record 49 of Set 8 | mountain brook
# Processing Record 50 of Set 8 | vagur
# Processing Record 1 of Set 9 | plouzane
# Processing Record 2 of Set 9 | camacupa
# Processing Record 3 of Set 9 | celestun
# Processing Record 4 of Set 9 | benjamin constant
# Processing Record 5 of Set 9 | bay roberts
# Processing Record 6 of Set 9 | dagana
# Processing Record 7 of Set 9 | waingapu
# Processing Record 8 of Set 9 | impfondo
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | broken hill
# Processing Record 11 of Set 9 | kisesa
# Processing Record 12 of Set 9 | bilma
# Processing Record 13 of Set 9 | achit
# Processing Record 14 of Set 9 | eufaula
# Processing Record 15 of Set 9 | kashi
# Processing Record 16 of Set 9 | monroe
# Processing Record 17 of Set 9 | mattru
# Processing Record 18 of Set 9 | rawson
# Processing Record 19 of Set 9 | bambous virieux
# Processing Record 20 of Set 9 | pelotas
# Processing Record 21 of Set 9 | poum
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | deputatskiy
# Processing Record 24 of Set 9 | bahia blanca
# Processing Record 25 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 26 of Set 9 | curuca
# Processing Record 27 of Set 9 | shakawe
# Processing Record 28 of Set 9 | dutse
# Processing Record 29 of Set 9 | sioux lookout
# Processing Record 30 of Set 9 | kpagouda
# City not found. Skipping...
# Processing Record 31 of Set 9 | cabo san lucas
# Processing Record 32 of Set 9 | sangar
# Processing Record 33 of Set 9 | guerrero negro
# Processing Record 34 of Set 9 | marystown
# Processing Record 35 of Set 9 | hirara
# Processing Record 36 of Set 9 | port hedland
# Processing Record 37 of Set 9 | sombor
# Processing Record 38 of Set 9 | nazca
# Processing Record 39 of Set 9 | santa helena
# Processing Record 40 of Set 9 | mildura
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | nhulunbuy
# Processing Record 43 of Set 9 | luzhou
# Processing Record 44 of Set 9 | takoradi
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | cap malheureux
# Processing Record 47 of Set 9 | radcliff
# Processing Record 48 of Set 9 | korla
# Processing Record 49 of Set 9 | takayama
# Processing Record 50 of Set 9 | tezu
# Processing Record 1 of Set 10 | mount isa
# Processing Record 2 of Set 10 | ust-karsk
# Processing Record 3 of Set 10 | waw
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | jiaojiang
# Processing Record 6 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 10 | auerbach
# Processing Record 8 of Set 10 | lompoc
# Processing Record 9 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 10 | marzuq
# Processing Record 12 of Set 10 | shache
# Processing Record 13 of Set 10 | sur
# Processing Record 14 of Set 10 | bandarbeyla
# Processing Record 15 of Set 10 | mayumba
# Processing Record 16 of Set 10 | jiangyou
# Processing Record 17 of Set 10 | sumbe
# Processing Record 18 of Set 10 | kalemie
# Processing Record 19 of Set 10 | jacareacanga
# Processing Record 20 of Set 10 | tomatlan
# Processing Record 21 of Set 10 | tiruvannamalai
# Processing Record 22 of Set 10 | fairbanks
# Processing Record 23 of Set 10 | san patricio
# Processing Record 24 of Set 10 | sambava
# Processing Record 25 of Set 10 | formosa
# Processing Record 26 of Set 10 | ouesso
# Processing Record 27 of Set 10 | parnamirim
# Processing Record 28 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 10 | sorong
# Processing Record 30 of Set 10 | araouane
# Processing Record 31 of Set 10 | mandalgovi
# Processing Record 32 of Set 10 | kavaratti
# Processing Record 33 of Set 10 | bedesa
# Processing Record 34 of Set 10 | ornskoldsvik
# Processing Record 35 of Set 10 | marquette
# Processing Record 36 of Set 10 | sapa
# Processing Record 37 of Set 10 | astana
# Processing Record 38 of Set 10 | mitzic
# Processing Record 39 of Set 10 | birin
# Processing Record 40 of Set 10 | stony mountain
# Processing Record 41 of Set 10 | senador pompeu
# Processing Record 42 of Set 10 | clyde river
# Processing Record 43 of Set 10 | lata
# Processing Record 44 of Set 10 | berdigestyakh
# Processing Record 45 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 10 | wajima
# Processing Record 47 of Set 10 | requena
# Processing Record 48 of Set 10 | dali
# Processing Record 49 of Set 10 | katobu
# Processing Record 50 of Set 10 | sola
# Processing Record 1 of Set 11 | mackay
# Processing Record 2 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 11 | shimoda
# Processing Record 4 of Set 11 | ilo
# Processing Record 5 of Set 11 | praya
# Processing Record 6 of Set 11 | ikom
# Processing Record 7 of Set 11 | walvis bay
# Processing Record 8 of Set 11 | arroyo
# Processing Record 9 of Set 11 | matagami
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | tabuk
# Processing Record 12 of Set 11 | pasighat
# Processing Record 13 of Set 11 | gander
# Processing Record 14 of Set 11 | rio de janeiro
# Processing Record 15 of Set 11 | pemba
# Processing Record 16 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | fethiye
# Processing Record 18 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 11 | teya
# Processing Record 20 of Set 11 | peleduy
# Processing Record 21 of Set 11 | ust-tarka
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | dhanaula
# Processing Record 24 of Set 11 | auki
# Processing Record 25 of Set 11 | san nicolas
# Processing Record 26 of Set 11 | tabou
# Processing Record 27 of Set 11 | bogo
# Processing Record 28 of Set 11 | kuching
# Processing Record 29 of Set 11 | gonen
# Processing Record 30 of Set 11 | malakal
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | peniche
# Processing Record 33 of Set 11 | constitucion
# Processing Record 34 of Set 11 | matara
# Processing Record 35 of Set 11 | preobrazheniye
# Processing Record 36 of Set 11 | rhyl
# Processing Record 37 of Set 11 | morant bay
# Processing Record 38 of Set 11 | mitsamiouli
# Processing Record 39 of Set 11 | katsuura
# Processing Record 40 of Set 11 | ormara
# Processing Record 41 of Set 11 | anadyr
# Processing Record 42 of Set 11 | dunedin
# Processing Record 43 of Set 11 | jalu
# Processing Record 44 of Set 11 | namatanai
# Processing Record 45 of Set 11 | lumut
# Processing Record 46 of Set 11 | gwadar
# Processing Record 47 of Set 11 | manyana
# Processing Record 48 of Set 11 | fasa
# Processing Record 49 of Set 11 | boyolangu
# Processing Record 50 of Set 11 | pingdingshan
# Processing Record 1 of Set 12 | petropavl
# Processing Record 2 of Set 12 | manicore
# Processing Record 3 of Set 12 | svetlyy
# Processing Record 4 of Set 12 | yeppoon
# Processing Record 5 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 12 | riachao
# Processing Record 7 of Set 12 | grindavik
# Processing Record 8 of Set 12 | coahuayana
# Processing Record 9 of Set 12 | zeya
# Processing Record 10 of Set 12 | general pico
# Processing Record 11 of Set 12 | powell river
# Processing Record 12 of Set 12 | adre
# Processing Record 13 of Set 12 | fujin
# Processing Record 14 of Set 12 | kamaishi
# Processing Record 15 of Set 12 | tuatapere
# Processing Record 16 of Set 12 | xai-xai
# Processing Record 17 of Set 12 | siniscola
# Processing Record 18 of Set 12 | shostka
# Processing Record 19 of Set 12 | namibe
# Processing Record 20 of Set 12 | barbacena
# Processing Record 21 of Set 12 | raozan
# City not found. Skipping...
# Processing Record 22 of Set 12 | antalaha
# Processing Record 23 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 24 of Set 12 | kismayo
# Processing Record 25 of Set 12 | urumqi
# Processing Record 26 of Set 12 | port augusta
# Processing Record 27 of Set 12 | mnogovershinnyy
# Processing Record 28 of Set 12 | nyurba
# Processing Record 29 of Set 12 | niquero
# Processing Record 30 of Set 12 | lyuban
# Processing Record 31 of Set 12 | noshiro
# Processing Record 32 of Set 12 | nouadhibou
# Processing Record 33 of Set 12 | gamba
# Processing Record 34 of Set 12 | tema
# Processing Record 35 of Set 12 | san pedro
# Processing Record 36 of Set 12 | maceio
# Processing Record 37 of Set 12 | shubarshi
# Processing Record 38 of Set 12 | nikki
# Processing Record 39 of Set 12 | antofagasta
# Processing Record 40 of Set 12 | wucheng
# Processing Record 41 of Set 12 | kutum
# Processing Record 42 of Set 12 | inirida
# Processing Record 43 of Set 12 | buraydah
# Processing Record 44 of Set 12 | pichayevo
# Processing Record 45 of Set 12 | badoc
# Processing Record 46 of Set 12 | port macquarie
# Processing Record 47 of Set 12 | grand gaube
# Processing Record 48 of Set 12 | turbo
# Processing Record 49 of Set 12 | zhigansk
# Processing Record 50 of Set 12 | teeli
# Processing Record 1 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 13 | imbituba
# Processing Record 3 of Set 13 | gravdal
# Processing Record 4 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 13 | cayenne
# Processing Record 6 of Set 13 | ust-koksa
# Processing Record 7 of Set 13 | upington
# Processing Record 8 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 13 | cockburn town
# Processing Record 10 of Set 13 | ambagarh chauki
# Processing Record 11 of Set 13 | shelburne
# Processing Record 12 of Set 13 | ngawen
# Processing Record 13 of Set 13 | aryiropoulion
# Processing Record 14 of Set 13 | batagay-alyta
# Processing Record 15 of Set 13 | skeldon
# Processing Record 16 of Set 13 | saint anthony
# Processing Record 17 of Set 13 | bo phloi
# Processing Record 18 of Set 13 | atar
# Processing Record 19 of Set 13 | ongole
# Processing Record 20 of Set 13 | waipawa
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | rocha
# Processing Record 23 of Set 13 | ilulissat
# Processing Record 24 of Set 13 | mulchen
# Processing Record 25 of Set 13 | yefremov
# Processing Record 26 of Set 13 | tirano
# Processing Record 27 of Set 13 | porto nacional
# Processing Record 28 of Set 13 | verkhnevilyuysk
# Processing Record 29 of Set 13 | irbeyskoye
# Processing Record 30 of Set 13 | kincardine
# Processing Record 31 of Set 13 | quetta
# Processing Record 32 of Set 13 | bend
# Processing Record 33 of Set 13 | banyo
# Processing Record 34 of Set 13 | san ramon
# Processing Record 35 of Set 13 | nedryhayliv
# Processing Record 36 of Set 13 | lakes entrance
# Processing Record 37 of Set 13 | jinxiang
# Processing Record 38 of Set 13 | alofi
# Processing Record 39 of Set 13 | prado
# Processing Record 40 of Set 13 | sorland
# Processing Record 41 of Set 13 | juegang
# Processing Record 42 of Set 13 | pitea
# Processing Record 43 of Set 13 | lohja
# Processing Record 44 of Set 13 | capinopolis
# Processing Record 45 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 13 | shitanjing
# Processing Record 47 of Set 13 | machinga
# Processing Record 48 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 13 | duz
# City not found. Skipping...
# Processing Record 50 of Set 13 | vanavara
# Processing Record 1 of Set 14 | kieta
# Processing Record 2 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 14 | javanrud
# Processing Record 4 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 14 | tateyama
# Processing Record 6 of Set 14 | copiapo
# Processing Record 7 of Set 14 | xuddur
# Processing Record 8 of Set 14 | mercedes
# Processing Record 9 of Set 14 | voh
# Processing Record 10 of Set 14 | goderich
# Processing Record 11 of Set 14 | vestmannaeyjar
# Processing Record 12 of Set 14 | ahuimanu
# Processing Record 13 of Set 14 | severomuysk
# Processing Record 14 of Set 14 | novoomskiy
# Processing Record 15 of Set 14 | launceston
# Processing Record 16 of Set 14 | cilegon
# Processing Record 17 of Set 14 | cabedelo
# Processing Record 18 of Set 14 | sri aman
# Processing Record 19 of Set 14 | natal
# Processing Record 20 of Set 14 | karasjok
# Processing Record 21 of Set 14 | mayskiy
# Processing Record 22 of Set 14 | belaya gora
# Processing Record 23 of Set 14 | visby
# Processing Record 24 of Set 14 | maragogi
# Processing Record 25 of Set 14 | westport
# Processing Record 26 of Set 14 | yantal
# Processing Record 27 of Set 14 | lincoln
# Processing Record 28 of Set 14 | punta
# Processing Record 29 of Set 14 | sayat
# Processing Record 30 of Set 14 | bezhetsk
# Processing Record 31 of Set 14 | lazaro cardenas
# Processing Record 32 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 33 of Set 14 | porto novo
# Processing Record 34 of Set 14 | daltenganj
# Processing Record 35 of Set 14 | tshikapa
# Processing Record 36 of Set 14 | roebourne
# Processing Record 37 of Set 14 | antsohihy
# Processing Record 38 of Set 14 | reo
# Processing Record 39 of Set 14 | oyem
# Processing Record 40 of Set 14 | suchilquitongo
# City not found. Skipping...
# Processing Record 41 of Set 14 | gurun
# Processing Record 42 of Set 14 | sorkjosen
# Processing Record 43 of Set 14 | necochea
# Processing Record 44 of Set 14 | paamiut
# Processing Record 45 of Set 14 | mandera
# Processing Record 46 of Set 14 | skjervoy
# Processing Record 47 of Set 14 | pringsewu
# Processing Record 48 of Set 14 | maungaturoto
# Processing Record 49 of Set 14 | turkistan
# Processing Record 50 of Set 14 | high level
# Processing Record 1 of Set 15 | hearst
# Processing Record 2 of Set 15 | jackson
# Processing Record 3 of Set 15 | opuwo
# Processing Record 4 of Set 15 | yei
# Processing Record 5 of Set 15 | bar harbor
# Processing Record 6 of Set 15 | khor
# Processing Record 7 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 8 of Set 15 | port-cartier
# Processing Record 9 of Set 15 | stonewall
# Processing Record 10 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 11 of Set 15 | manggar
# Processing Record 12 of Set 15 | annau
# Processing Record 13 of Set 15 | mozarlandia
# Processing Record 14 of Set 15 | san jeronimo
# Processing Record 15 of Set 15 | tancitaro
# Processing Record 16 of Set 15 | athabasca
# Processing Record 17 of Set 15 | bhatkal
# Processing Record 18 of Set 15 | kawalu
# Processing Record 19 of Set 15 | sohag
# Processing Record 20 of Set 15 | xinmin
# Processing Record 21 of Set 15 | gulariya
# Processing Record 22 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 15 | warmbad
# Processing Record 24 of Set 15 | zapolyarnyy
# Processing Record 25 of Set 15 | pangody
# Processing Record 26 of Set 15 | qaqortoq
# Processing Record 27 of Set 15 | wamba
# Processing Record 28 of Set 15 | toropets
# Processing Record 29 of Set 15 | vega de alatorre
# Processing Record 30 of Set 15 | adet
# Processing Record 31 of Set 15 | sao felix do xingu
# Processing Record 32 of Set 15 | bacungan
# Processing Record 33 of Set 15 | leshukonskoye
# Processing Record 34 of Set 15 | okhotsk
# Processing Record 35 of Set 15 | loralai
# Processing Record 36 of Set 15 | menongue
# Processing Record 37 of Set 15 | flin flon
# Processing Record 38 of Set 15 | khandyga
# Processing Record 39 of Set 15 | coihaique
# Processing Record 40 of Set 15 | port-gentil
# Processing Record 41 of Set 15 | orocue
# Processing Record 42 of Set 15 | candolim
# Processing Record 43 of Set 15 | samfya
# Processing Record 44 of Set 15 | verkhnyaya maksakovka
# Processing Record 45 of Set 15 | strezhevoy
# Processing Record 46 of Set 15 | kargasok
# Processing Record 47 of Set 15 | sosnovka
# Processing Record 48 of Set 15 | houston
# Processing Record 49 of Set 15 | half moon bay
# Processing Record 50 of Set 15 | fare
# Processing Record 1 of Set 16 | north bend
# Processing Record 2 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 16 | miles city
# Processing Record 4 of Set 16 | paignton
# Processing Record 5 of Set 16 | arkhangelskoye
# Processing Record 6 of Set 16 | inhuma
# Processing Record 7 of Set 16 | chumikan
# Processing Record 8 of Set 16 | murray bridge
# Processing Record 9 of Set 16 | noumea
# Processing Record 10 of Set 16 | heihe
# Processing Record 11 of Set 16 | camacha
# Processing Record 12 of Set 16 | syedove
# Processing Record 13 of Set 16 | sawtell
# Processing Record 14 of Set 16 | portales
# Processing Record 15 of Set 16 | bereda
# Processing Record 16 of Set 16 | wewak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Atuona      PF  -9.8000 -139.0333     80.13        74          85
# 1       Bluff      NZ -46.6000  168.3333     46.00        91         100
# 2     Tautira      PF -17.7333 -149.1500     87.80        62          20
# 3  Whitehorse      CA  60.7161 -135.0538     57.20        21           1
# 4      Castro      BR -24.7911  -50.0119     59.13        92          99
# 5      Laguna      US  38.4210 -121.4238     61.00        55          40
# 6  Port Hardy      CA  50.6996 -127.4199     51.80        82          75
# 7   Ketchikan      US  55.3422 -131.6461     60.80        29           1
# 8      Nemuro      JP  43.3236  145.5750     39.20        38          40
# 9      Albany      US  42.6001  -73.9662     51.80        53          20
#
#    Wind Speed Current Description
# 0       15.46     overcast clouds
# 1       11.99     overcast clouds
# 2        5.75          light rain
# 3       10.36           clear sky
# 4        3.29     overcast clouds
# 5       10.36    scattered clouds
# 6        3.44          light rain
# 7       11.50           clear sky
# 8       17.27    scattered clouds
# 9       20.71          few clouds

# %%
# Create the output file (CSV).
output_data_file = "/Users/angelica_villanueva/Downloads/weather_database/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label='City_ID')
